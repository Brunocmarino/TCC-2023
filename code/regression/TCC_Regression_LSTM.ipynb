# %% [markdown]
# Nesse projeto uso LSTM para descobrir qual é o preço de fechamento do bitcoin. Uso 5 features relativas ao candle de negociação diária e prevejo o preço de fechamento do dia seguinte

# %%
# !pip install keras-tuner
# !pip install tensorflow
# !pip install numpy
# !pip install pandas
# Out:
# Requirement already satisfied: keras-tuner in /usr/local/lib/python3.10/dist-packages (1.4.5)
# Requirement already satisfied: keras-core in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (0.1.7)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (23.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (2.31.0)
# Requirement already satisfied: kt-legacy in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (1.0.5)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras-core->keras-tuner) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras-core->keras-tuner) (1.23.5)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras-core->keras-tuner) (13.6.0)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras-core->keras-tuner) (0.0.7)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras-core->keras-tuner) (3.9.0)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.10/dist-packages (from keras-core->keras-tuner) (0.1.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2023.7.22)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras-core->keras-tuner) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras-core->keras-tuner) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras-core->keras-tuner) (0.1.2)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.14.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes==0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: numpy>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.5.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.34.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.59.0)
# Requirement already satisfied: tensorboard<2.15,>=2.14 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.14.1)
# Requirement already satisfied: tensorflow-estimator<2.15,>=2.14.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.14.0)
# Requirement already satisfied: keras<2.15,>=2.14.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.14.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.41.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (3.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.15,>=2.14->tensorflow) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow) (3.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.23.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
#Importar as bibliotecas necessárias
import os
import pandas as pd
import numpy as np
import math
import datetime
import time

# Importar sklearn para avaliar o modelo
from sklearn.metrics import mean_squared_error, mean_absolute_error, explained_variance_score, r2_score
from sklearn.metrics import mean_poisson_deviance, mean_gamma_deviance, accuracy_score
from sklearn.preprocessing  import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import confusion_matrix
# from scikeras.wrappers import KerasRegressor
# from tensorflow.keras.wrappers.scikit_learn import KerasRegressor


from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint as sp_randint
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint as sp_randint
# Importar tensorflow para construir o modelo
import tensorflow as tf
import keras
from keras import optimizers
from keras.optimizers import Adam
from keras.models import Sequential, Model, load_model
from keras.layers import *
from keras.callbacks import ModelCheckpoint, History, EarlyStopping
from keras.losses import MeanSquaredError
from keras.metrics import RootMeanSquaredError
from keras.optimizers import Adam

# Importar bibliotecas para plotar gráficos

import matplotlib.pyplot as plt
from itertools import cycle
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots

# %% [markdown]
# ## Variaveis Globais

# %%
TIME_STEP = 7           #número de dias usados para prever o futuro
JUMP_STEP = 1
NUM_FEATURES = 5
NUM_PREDICT_FUTURE = 30      #número do dia a serem preditos no futuro (prever o próximo dia? Prever o 7º dia?)
PATH = './drive/MyDrive/TCC/single_lstm_regression8/'
THRESHOLD = 5

# %% [markdown]
# ## Definição das Seeds

# %%
import tensorflow as tf
import numpy as np

# Defina a semente do TensorFlow
tf.random.set_seed(0)

# Defina a semente do NumPy
np.random.seed(0)

# %% [markdown]
# ## Importar a Base de Dados

# %%
ticker = 'BTC-USD'
#1410825600
initial_period = int(time.mktime(datetime.datetime(2014, 9, 16, 0, 0).timetuple()))

#1675814400
final_period = int(time.mktime(datetime.datetime(2023, 10, 31, 0, 0).timetuple()))
# 3067 valores. 2300 é 75%
interval = '1d' # 1d, 1wk, 1m

query_string = f'https://query1.finance.yahoo.com/v7/finance/download/{ticker}?period1={initial_period}&period2={final_period}&interval={interval}&events=history&includeAdjustedClose=true'

data = pd.read_csv(query_string)
df = pd.DataFrame(data, columns=['Date', 'Open', 'High', 'Low', 'Close', 'Volume'])
df.index = pd.to_datetime(df['Date'], format='%Y-%m-%d')

# %% [markdown]
# Função para escolher os dados utilizados de forma sequencial. A cada t valores

# %%
# def selecionaValores(df, jump_step):
#   return df[0::jump_step]

# df = selecionaValores(df, JUMP_STEP)

# %% [markdown]
# Preparação dos Dados:

# %%
# Retira a Data e coloca como Index
df.index = df.pop('Date')

data.dropna(inplace=True)
data.reset_index(inplace = True)

# %%
# Definir os dataframes dos objetivos a serem alcançados pelo modelo. O Y. Baseados no TimeStep e numero do dia a ser predito

ignoreDays = TIME_STEP + NUM_PREDICT_FUTURE - 1
index = np.array(df.index)[ignoreDays:]

# Dataframe com o valor de fechamento
target_df_Close = pd.DataFrame(df['Close'], index, ['Close']).rename(columns={'Close':'YClose'})

# Dataframe com a variação nominal entre os dias
array_change = np.array(target_df_Close.YClose) - np.array(df['Close'])[TIME_STEP-1 : -NUM_PREDICT_FUTURE]
target_df_Change = pd.DataFrame(array_change, index, columns=['Close']).rename(columns={'Close':'YChange'})

# Dataframe com a variação percentual entre os dias
array_variation = np.array(target_df_Change.YChange) / np.array(df['Close'])[TIME_STEP-1 : -NUM_PREDICT_FUTURE]
target_df_Variation = pd.DataFrame(array_variation*100, index, ['Close']).rename(columns={'Close':'YVariation'})


# Dataframe com a Classe baseado na variação percentual entre os dias
def defineClass(variation, THRESHOLD):
  if variation > THRESHOLD:
    return 2
  elif variation < -THRESHOLD:
    return 0
  else:
    return 1
# Apply the defineClass function to each data point in the array_variation
classifications = [defineClass(variation*100, 3) for variation in array_variation]
target_df_Class3 = pd.DataFrame(classifications, index, ['Close']).rename(columns={'Close':'YClass'})

# Apply the defineClass function to each data point in the array_variation
classifications = [defineClass(variation*100, 5) for variation in array_variation]
target_df_Class5 = pd.DataFrame(classifications, index, ['Close']).rename(columns={'Close':'YClass'})

# Apply the defineClass function to each data point in the array_variation
classifications = [defineClass(variation*100, 7) for variation in array_variation]
target_df_Class7 = pd.DataFrame(classifications, index, ['Close']).rename(columns={'Close':'YClass'})

# %%
# Imprimir informações sobre o tamanho das séries de dados
print(f'df.Close.size: {df.Close.size}')
print(f'target_df_Close.size: {target_df_Close.size}')
print(f'target_df_Change.size: {target_df_Change.size}')
print(f'target_df_Variation.size: {target_df_Variation.size}')
print()
# Out:
# df.Close.size: 3332
# target_df_Close.size: 3296
# target_df_Change.size: 3296
# target_df_Variation.size: 3296

# %%
#plt.plot(df.index, df['Close'])

# %% [markdown]
# ## Divisão em Treino, Validação e Teste

# %%
# Divisão entre 70% treino, 10% validação e 20% teste
size = len(target_df_Close)
train_size = int(size * 0.7)
validation_size = int(size * 0.1)
test_size = size - train_size - validation_size

x_train_data = df[: train_size + TIME_STEP - 1]
x_val_data = df[ train_size : (train_size + validation_size + TIME_STEP - 1)]
x_test_data = df[train_size + validation_size : -NUM_PREDICT_FUTURE]

y_train_data = target_df_Close[: train_size]
y_val_data = target_df_Close[train_size : (train_size + validation_size)]
y_test_data = target_df_Close[(train_size + validation_size) :]

#Serão usados nas etapas finais do projeto
y_train_class3 = target_df_Class3[: train_size]
y_val_class3 = target_df_Class3[train_size : (train_size + validation_size)]
y_test_class3 = target_df_Class3[(train_size + validation_size) :]

y_train_class5 = target_df_Class5[: train_size]
y_val_class5 = target_df_Class5[train_size : (train_size + validation_size)]
y_test_class5 = target_df_Class5[(train_size + validation_size) :]

y_train_class7 = target_df_Class7[: train_size]
y_val_class7 = target_df_Class7[train_size : (train_size + validation_size)]
y_test_class7 = target_df_Class7[(train_size + validation_size) :]

y_train_variation = target_df_Variation[: train_size]
y_val_variation = target_df_Variation[train_size : (train_size + validation_size)]
y_test_variation = target_df_Variation[(train_size + validation_size) :]

# %%
# Imprimir informações sobre os tamanhos dos dados
print('Tamanhos dos dados:')
print(f'size: {size}')
print(f'train_size: {train_size}')
print(f'validation_size: {validation_size}')
print(f'test_size: {test_size}')
print()
# Out:
# Tamanhos dos dados:
# size: 3296
# train_size: 2307
# validation_size: 329
# test_size: 660

# %%
# Imprimir os tamanhos dos dados em linhas separadas
print('x_train_data.shape:', x_train_data.shape)
print('x_val_data.shape:', x_val_data.shape)
print('x_test_data.shape:', x_test_data.shape)
print('y_train_data.shape:', y_train_data.shape)
print('y_val_data.shape:', y_val_data.shape)
print('y_test_data.shape:', y_test_data.shape)
print()
# Out:
# x_train_data.shape: (2313, 5)
# x_val_data.shape: (335, 5)
# x_test_data.shape: (666, 5)
# y_train_data.shape: (2307, 1)
# y_val_data.shape: (329, 1)
# y_test_data.shape: (660, 1)

# %%
#Transforma os dados para suavizar as variações em escala absoluta
# Transforma input data
scaler_train_input = MinMaxScaler(feature_range=(0, 1))
scaled_train_input = scaler_train_input.fit_transform(x_train_data)

scaled_val_input = scaler_train_input.transform(x_val_data)
scaled_test_input = scaler_train_input.transform(x_test_data)

# Transforma output data para o log do resultado
# scaled_train_output = np.array(y_train_data)
# scaled_val_output = np.array(y_val_data)
# scaled_test_output = np.array(y_test_data)
scaled_train_output = np.log10(np.array(y_train_data))
scaled_val_output = np.log10(np.array(y_val_data))
scaled_test_output = np.log10(np.array(y_test_data))

# %%
def createDataset(x, y, time_step=1):
  input = []
  output = []
  for i in range(len(y)):
    row = np.array([e for e in x[i : i + time_step]])
    input.append(row)
    output.append(y[i])
  return np.array(input), np.array(output)

x_train, y_train = createDataset(scaled_train_input, scaled_train_output, TIME_STEP)
x_val, y_val = createDataset(scaled_val_input, scaled_val_output, TIME_STEP)
x_test, y_test = createDataset(scaled_test_input, scaled_test_output, TIME_STEP)

# %%
# Imprimir informações sobre as formas dos DataFrames e arrays
print('Formas dos DataFrames e arrays:')
print(f'df.shape: {df.shape}')
print(f'x_train.shape: {x_train.shape}, y_train.shape: {y_train.shape}')
print(f'x_val.shape: {x_val.shape}, y_val.shape: {y_val.shape}')
print(f'x_test.shape: {x_test.shape}, y_test.shape: {y_test.shape}')
print()
# Out:
# Formas dos DataFrames e arrays:
# df.shape: (3332, 5)
# x_train.shape: (2307, 7, 5), y_train.shape: (2307, 1)
# x_val.shape: (329, 7, 5), y_val.shape: (329, 1)
# x_test.shape: (660, 7, 5), y_test.shape: (660, 1)

# %% [markdown]
# ## Construção do Modelo LSTM

# %% [markdown]
# ### Random Search com LSTM

# %%
import keras_tuner as kt
import keras.backend as K

def build_singleLayer_lstm_model(hp):
  #Variables to change with RandomSearch
  units = hp.Int('num_lstm_units', min_value=16, max_value=128, step=16)
  dropout = hp.Float('dropout_rate', min_value=0, max_value=0.4)
  learningRate = hp.Float('learning_rate', min_value=0.001, max_value=0.1, sampling='log')
  activation = hp.Choice('activation', ['tanh', 'relu'])

  model = keras.Sequential()
  model.add(LSTM(
      units = units,
      return_sequences=False,
      input_shape = (x_train.shape[1], x_train.shape[2]),
      activation=activation
      ))
  model.add(Dropout(dropout))
  model.add(Dense(1))
  optimizer = Adam(learning_rate=learningRate)
  model.compile(loss='mean_squared_error', optimizer=optimizer,metrics=['mean_squared_error'])
  return model

earlystopping = EarlyStopping(monitor='val_loss', patience=25, restore_best_weights=True)

tuner = kt.RandomSearch(
    build_singleLayer_lstm_model,
    objective='val_loss',
    max_trials=100,
    executions_per_trial=1,
    directory=PATH,
    overwrite=True,
    project_name='lstm_tuning')

tuner.search_space_summary()

tuner.search(x_train, y_train, epochs=25, validation_data=(x_val, y_val), callbacks=[earlystopping], batch_size=32, verbose=1)
tuner.results_summary()

#Get the best model and hyperparameters
best_model = tuner.get_best_models(num_models=1)[0];
best_model.save(PATH + 'best_model_tunner.hdf5');
best_model.build(x_train.shape);
best_model.summary();
best_hyperparameters = tuner.get_best_hyperparameters(num_trials=1)[0];
# Out:
# Trial 100 Complete [00h 00m 29s]
# val_loss: 0.007492858450859785
#
# Best val_loss So Far: 0.006531471386551857
# Total elapsed time: 00h 56m 19s
# Results summary
# Results in ./drive/MyDrive/TCC/single_lstm_regression8/lstm_tuning
# Showing 10 best trials
# Objective(name="val_loss", direction="min")
#
# Trial 062 summary
# Hyperparameters:
# num_lstm_units: 48
# dropout_rate: 0.2203676514301789
# learning_rate: 0.07573740073903526
# activation: tanh
# Score: 0.006531471386551857
#
# Trial 046 summary
# Hyperparameters:
# num_lstm_units: 32
# dropout_rate: 0.30089450373685755
# learning_rate: 0.04689451455948989
# activation: tanh
# Score: 0.007150677498430014
#
# Trial 049 summary
# Hyperparameters:
# num_lstm_units: 80
# dropout_rate: 0.3561060777784304
# learning_rate: 0.027667339170777613
# activation: tanh
# Score: 0.007151361089199781
#
# Trial 085 summary
# Hyperparameters:
# num_lstm_units: 64
# dropout_rate: 0.05070056246809638
# learning_rate: 0.0017887307871975
# activation: tanh
# Score: 0.007187427952885628
#
# Trial 089 summary
# Hyperparameters:
# num_lstm_units: 80
# dropout_rate: 0.04382415528222743
# learning_rate: 0.08607891267222294
# activation: tanh
# Score: 0.007221520412713289
#
# Trial 077 summary
# Hyperparameters:
# num_lstm_units: 48
# dropout_rate: 0.34161505110323725
# learning_rate: 0.032522097090204975
# activation: tanh
# Score: 0.007284318096935749
#
# Trial 040 summary
# Hyperparameters:
# num_lstm_units: 112
# dropout_rate: 0.015565905619321274
# learning_rate: 0.037685920830259546
# activation: tanh
# Score: 0.007408554200083017
#
# Trial 099 summary
# Hyperparameters:
# num_lstm_units: 80
# dropout_rate: 0.10335323014061887
# learning_rate: 0.059237449094478485
# activation: tanh
# Score: 0.007492858450859785
#
# Trial 015 summary
# Hyperparameters:
# num_lstm_units: 48
# dropout_rate: 0.104759012243763
# learning_rate: 0.07755867889032285
# activation: tanh
# Score: 0.0075052762404084206
#
# Trial 021 summary
# Hyperparameters:
# num_lstm_units: 128
# dropout_rate: 0.29013684191436834
# learning_rate: 0.0013437185489870093
# activation: tanh
# Score: 0.007603303994983435
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 48)                10368
#
#  dropout (Dropout)           (None, 48)                0
#
#  dense (Dense)               (None, 1)                 49
#
# =================================================================
# Total params: 10417 (40.69 KB)
# Trainable params: 10417 (40.69 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Mostra Treina o melhor modelo com EarlyStop

# %%
best_model = load_model(PATH + 'best_model_tunner.hdf5')
best_model.build(x_train.shape);
best_model.summary();

earlystopping = EarlyStopping(monitor='val_loss', patience=100, restore_best_weights=True)

#Define um checkpoint para a melhor época
checkpoint_path = PATH + 'best_model_earlyStop.hdf5'
checkpoint = ModelCheckpoint(filepath=checkpoint_path,
                             monitor='val_loss',
                             verbose=1,
                             save_best_only=True,
                             mode='min')
callbacks = [checkpoint, earlystopping]
#Train the best model
history = best_model.fit(x_train, y_train, epochs=500, batch_size=32, validation_data=(x_val, y_val), verbose=1,
                              callbacks=callbacks)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 48)                10368
#
#  dropout (Dropout)           (None, 48)                0
#
#  dense (Dense)               (None, 1)                 49
#
# =================================================================
# Total params: 10417 (40.69 KB)
# Trainable params: 10417 (40.69 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.1
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.2
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.3
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.4
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.5
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.6
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.7
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.8
# Epoch 1/500
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.9
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer._variables.10
# 67/73 [==========================>...] - ETA: 0s - loss: 0.6320 - mean_squared_error: 0.6320
# Epoch 1: val_loss improved from inf to 0.16282, saving model to ./drive/MyDrive/TCC/single_lstm_regression8/best_model_earlyStop.hdf5
# 73/73 [==============================] - 4s 17ms/step - loss: 0.5943 - mean_squared_error: 0.5943 - val_loss: 0.1628 - val_mean_squared_error: 0.1628
# Epoch 2/500
# 72/73 [============================>.] - ETA: 0s - loss: 0.0843 - mean_squared_error: 0.0843
# Epoch 2: val_loss improved from 0.16282 to 0.08349, saving model to ./drive/MyDrive/TCC/single_lstm_regression8/best_model_earlyStop.hdf5
# 73/73 [==============================] - 1s 9ms/step - loss: 0.0843 - mean_squared_error: 0.0843 - val_loss: 0.0835 - val_mean_squared_error: 0.0835
# Epoch 3/500
# 70/73 [===========================>..] - ETA: 0s - loss: 0.0576 - mean_squared_error: 0.0576
# Epoch 3: val_loss improved from 0.08349 to 0.03363, saving model to ./drive/MyDrive/TCC/single_lstm_regression8/best_model_earlyStop.hdf5
# 73/73 [==============================] - 1s 14ms/step - loss: 0.0573 - mean_squared_error: 0.0573 - val_loss: 0.0336 - val_mean_squared_error: 0.0336
# Epoch 4/500
# 70/73 [===========================>..] - ETA: 0s - loss: 0.0510 - mean_squared_error: 0.0510
# Epoch 4: val_loss did not improve from 0.03363
# 73/73 [==============================] - 1s 14ms/step - loss: 0.0510 - mean_squared_error: 0.0510 - val_loss: 0.0436 - val_mean_squared_error: 0.0436
# Epoch 5/500
# 70/73 [===========================>..] - ETA: 0s - loss: 0.0398 - mean_squared_error: 0.0398
# Epoch 5: val_loss did not improve from 0.03363
# 73/73 [==============================] - 1s 14ms/step - loss: 0.0399 - mean_squared_error: 0.0399 - val_loss: 0.1458 - val_mean_squared_error: 0.1458
# Epoch 6/500
# 69/73 [===========================>..] - ETA: 0s - loss: 0.0425 - mean_squared_error: 0.0425
# Epoch 6: val_loss did not improve from 0.03363
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0420 - mean_squared_error: 0.0420 - val_loss: 0.0626 - val_mean_squared_error: 0.0626
# Epoch 7/500
# 70/73 [===========================>..] - ETA: 0s - loss: 0.0375 - mean_squared_error: 0.0375
# Epoch 7: val_loss did not improve from 0.03363
# 73/73 [==============================] - 1s 14ms/step - loss: 0.0371 - mean_squared_error: 0.0371 - val_loss: 0.0369 - val_mean_squared_error: 0.0369
# Epoch 8/500
# 72/73 [============================>.] - ETA: 0s - loss: 0.0347 - mean_squared_error: 0.0347
# Epoch 8: val_loss did not improve from 0.03363
# 73/73 [==============================] - 1s 14ms/step - loss: 0.0347 - mean_squared_error: 0.0347 - val_loss: 0.0657 - val_mean_squared_error: 0.0657
# Epoch 9/500
# 72/73 [============================>.] - ETA: 0s - loss: 0.0359 - mean_squared_error: 0.0359
# Epoch 9: val_loss improved from 0.03363 to 0.01937, saving model to ./drive/MyDrive/TCC/single_lstm_regression8/best_model_earlyStop.hdf5
# 73/73 [==============================] - 2s 23ms/step - loss: 0.0359 - mean_squared_error: 0.0359 - val_loss: 0.0194 - val_mean_squared_error: 0.0194
# Epoch 10/500
# 73/73 [==============================] - ETA: 0s - loss: 0.0356 - mean_squared_error: 0.0356
# Epoch 10: val_loss did not improve from 0.01937
# 73/73 [==============================] - 2s 22ms/step - loss: 0.0356 - mean_squared_error: 0.0356 - val_loss: 0.0381 - val_mean_squared_error: 0.0381
# Epoch 11/500
# 71/73 [============================>.] - ETA: 0s - loss: 0.0320 - mean_squared_error: 0.0320
# Epoch 11: val_loss did not improve from 0.01937
# 73/73 [==============================] - 2s 21ms/step - loss: 0.0319 - mean_squared_error: 0.0319 - val_loss: 0.0619 - val_mean_squared_error: 0.0619
# Epoch 12/500
# 73/73 [==============================] - ETA: 0s - loss: 0.0359 - mean_squared_error: 0.0359
# Epoch 12: val_loss did not improve from 0.01937
# 73/73 [==============================] - 2s 21ms/step - loss: 0.0359 - mean_squared_error: 0.0359 - val_loss: 0.0326 - val_mean_squared_error: 0.0326
# Epoch 13/500
# 70/73 [===========================>..] - ETA: 0s - loss: 0.0296 - mean_squared_error: 0.0296
# Epoch 13: val_loss did not improve from 0.01937
# 73/73 [==============================] - 1s 16ms/step - loss: 0.0300 - mean_squared_error: 0.0300 - val_loss: 0.0477 - val_mean_squared_error: 0.0477
# Epoch 14/500
# 73/73 [==============================] - ETA: 0s - loss: 0.0289 - mean_squared_error: 0.0289
# Epoch 14: val_loss did not improve from 0.01937
# 73/73 [==============================] - 1s 13ms/step - loss: 0.0289 - mean_squared_error: 0.0289 - val_loss: 0.0424 - val_mean_squared_error: 0.0424
# Epoch 15/500
# 70/73 [===========================>..] - ETA: 0s - loss: 0.0253 - mean_squared_error: 0.0253
# Epoch 15: val_loss improved from 0.01937 to 0.00863, saving model to ./drive/MyDrive/TCC/single_lstm_regression8/best_model_earlyStop.hdf5
# 73/73 [==============================] - 1s 17ms/step - loss: 0.0252 - mean_squared_error: 0.0252 - val_loss: 0.0086 - val_mean_squared_error: 0.0086
# Epoch 16/500
# 70/73 [===========================>..] - ETA: 0s - loss: 0.0261 - mean_squared_error: 0.0261
# Epoch 16: val_loss did not improve from 0.00863
# 73/73 [==============================] - 1s 15ms/step - loss: 0.0260 - mean_squared_error: 0.0260 - val_loss: 0.0333 - val_mean_squared_error: 0.0333
# Epoch 17/500
# 72/73 [============================>.] - ETA: 0s - loss: 0.0233 - mean_squared_error: 0.0233
# Epoch 17: val_loss did not improve from 0.00863
# 73/73 [==============================] - 1s 13ms/step - loss: 0.0233 - mean_squared_error: 0.0233 - val_loss: 0.0591 - val_mean_squared_error: 0.0591
# Epoch 18/500
# 73/73 [==============================] - ETA: 0s - loss: 0.0243 - mean_squared_error: 0.0243
# Epoch 18: val_loss did not improve from 0.00863
# 73/73 [==============================] - 1s 14ms/step - loss: 0.0243 - mean_squared_error: 0.0243 - val_loss: 0.0206 - val_mean_squared_error: 0.0206
# Epoch 19/500
# 72/73 [============================>.] - ETA: 0s - loss: 0.0240 - mean_squared_error: 0.0240
# Epoch 19: val_loss did not improve from 0.00863
# 73/73 [==============================] - 1s 15ms/step - loss: 0.0240 - mean_squared_error: 0.0240 - val_loss: 0.0154 - val_mean_squared_error: 0.0154
# Epoch 20/500
# 69/73 [===========================>..] - ETA: 0s - loss: 0.0227 - mean_squared_error: 0.0227
# Epoch 20: val_loss did not improve from 0.00863
# 73/73 [==============================] - 1s 14ms/step - loss: 0.0227 - mean_squared_error: 0.0227 - val_loss: 0.0130 - val_mean_squared_error: 0.0130
# Epoch 21/500
# 69/73 [===========================>..] - ETA: 0s - loss: 0.0224 - mean_squared_error: 0.0224
# Epoch 21: val_loss did not improve from 0.00863
# 73/73 [==============================] - 1s 11ms/step - loss: 0.0225 - mean_squared_error: 0.0225 - val_loss: 0.0388 - val_mean_squared_error: 0.0388
# Epoch 22/500
# 68/73 [==========================>...] - ETA: 0s - loss: 0.0216 - mean_squared_error: 0.0216
# Epoch 22: val_loss did not improve from 0.00863
# 73/73 [==============================] - 1s 15ms/step - loss: 0.0218 - mean_squared_error: 0.0218 - val_loss: 0.0419 - val_mean_squared_error: 0.0419
# Epoch 23/500
# 71/73 [============================>.] - ETA: 0s - loss: 0.0208 - mean_squared_error: 0.0208
# Epoch 23: val_loss did not improve from 0.00863
# 73/73 [==============================] - 2s 22ms/step - loss: 0.0206 - mean_squared_error: 0.0206 - val_loss: 0.0791 - val_mean_squared_error: 0.0791
# Epoch 24/500
# 70/73 [===========================>..] - ETA: 0s - loss: 0.0216 - mean_squared_error: 0.0216
# Epoch 24: val_loss did not improve from 0.00863
# 73/73 [==============================] - 2s 22ms/step - loss: 0.0215 - mean_squared_error: 0.0215 - val_loss: 0.0290 - val_mean_squared_error: 0.0290
# Epoch 25/500
# 73/73 [==============================] - ETA: 0s - loss: 0.0192 - mean_squared_error: 0.0192
# Epoch 25: val_loss did not improve from 0.00863
# 73/73 [==============================] - 2s 21ms/step - loss: 0.0192 - mean_squared_error: 0.0192 - val_loss: 0.0159 - val_mean_squared_error: 0.0159
# Epoch 26/500
# 72/73 [============================>.] - ETA: 0s - loss: 0.0208 - mean_squared_error: 0.0208
# Epoch 26: val_loss improved from 0.00863 to 0.00749, saving model to ./drive/MyDrive/TCC/single_lstm_regression8/best_model_earlyStop.hdf5
# 73/73 [==============================] - 2s 28ms/step - loss: 0.0208 - mean_squared_error: 0.0208 - val_loss: 0.0075 - val_mean_squared_error: 0.0075
# Epoch 27/500
# 71/73 [============================>.] - ETA: 0s - loss: 0.0203 - mean_squared_error: 0.0203
# Epoch 27: val_loss did not improve from 0.00749
# 73/73 [==============================] - 1s 16ms/step - loss: 0.0204 - mean_squared_error: 0.0204 - val_loss: 0.0293 - val_mean_squared_error: 0.0293
# Epoch 28/500
# 73/73 [==============================] - ETA: 0s - loss: 0.0181 - mean_squared_error: 0.0181
# Epoch 28: val_loss did not improve from 0.00749
# 73/73 [==============================] - 1s 15ms/step - loss: 0.0181 - mean_squared_error: 0.0181 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 29/500
# 73/73 [==============================] - ETA: 0s - loss: 0.0192 - mean_squared_error: 0.0192
# Epoch 29: val_loss did not improve from 0.00749
# 73/73 [==============================] - 1s 13ms/step - loss: 0.0192 - mean_squared_error: 0.0192 - val_loss: 0.0507 - val_mean_squared_error: 0.0507
# Epoch 30/500
# 73/73 [==============================] - ETA: 0s - loss: 0.0183 - mean_squared_error: 0.0183
# Epoch 30: val_loss did not improve from 0.00749
# 73/73 [==============================] - 1s 14ms/step - loss: 0.0183 - mean_squared_error: 0.0183 - val_loss: 0.1164 - val_mean_squared_error: 0.1164
# Epoch 31/500
# 72/73 [============================>.] - ETA: 0s - loss: 0.0214 - mean_squared_error: 0.0214
# Epoch 31: val_loss did not improve from 0.00749
# 73/73 [==============================] - 1s 16ms/step - loss: 0.0214 - mean_squared_error: 0.0214 - val_loss: 0.0202 - val_mean_squared_error: 0.0202
# Epoch 32/500
# 68/73 [==========================>...] - ETA: 0s - loss: 0.0190 - mean_squared_error: 0.0190
# Epoch 32: val_loss did not improve from 0.00749
# 73/73 [==============================] - 1s 15ms/step - loss: 0.0188 - mean_squared_error: 0.0188 - val_loss: 0.0363 - val_mean_squared_error: 0.0363
# Epoch 33/500
# 71/73 [============================>.] - ETA: 0s - loss: 0.0191 - mean_squared_error: 0.0191
# Epoch 33: val_loss did not improve from 0.00749
# 73/73 [==============================] - 1s 14ms/step - loss: 0.0190 - mean_squared_error: 0.0190 - val_loss: 0.0099 - val_mean_squared_error: 0.0099
# Epoch 34/500
# 71/73 [============================>.] - ETA: 0s - loss: 0.0186 - mean_squared_error: 0.0186
# Epoch 34: val_loss did not improve from 0.00749
# 73/73 [==============================] - 1s 13ms/step - loss: 0.0186 - mean_squared_error: 0.0186 - val_loss: 0.0092 - val_mean_squared_error: 0.0092
# Epoch 35/500
# 71/73 [============================>.] - ETA: 0s - loss: 0.0188 - mean_squared_error: 0.0188
# Epoch 35: val_loss did not improve from 0.00749
# 73/73 [==============================] - 1s 15ms/step - loss: 0.0187 - mean_squared_error: 0.0187 - val_loss: 0.0169 - val_mean_squared_error: 0.0169
# Epoch 36/500
# 72/73 [============================>.] - ETA: 0s - loss: 0.0182 - mean_squared_error: 0.0182
# Epoch 36: val_loss did not improve from 0.00749
# 73/73 [==============================] - 2s 23ms/step - loss: 0.0182 - mean_squared_error: 0.0182 - val_loss: 0.0135 - val_mean_squared_error: 0.0135
# Epoch 37/500
# 69/73 [===========================>..] - ETA: 0s - loss: 0.0173 - mean_squared_error: 0.0173
# Epoch 37: val_loss did not improve from 0.00749
# 73/73 [==============================] - 1s 20ms/step - loss: 0.0176 - mean_squared_error: 0.0176 - val_loss: 0.0356 - val_mean_squared_error: 0.0356
# Epoch 38/500
# 69/73 [===========================>..] - ETA: 0s - loss: 0.0175 - mean_squared_error: 0.0175
# Epoch 38: val_loss did not improve from 0.00749
# 73/73 [==============================] - 1s 20ms/step - loss: 0.0176 - mean_squared_error: 0.0176 - val_loss: 0.0203 - val_mean_squared_error: 0.0203
# Epoch 39/500
# 72/73 [============================>.] - ETA: 0s - loss: 0.0173 - mean_squared_error: 0.0173
# Epoch 39: val_loss did not improve from 0.00749
# 73/73 [==============================] - 2s 24ms/step - loss: 0.0173 - mean_squared_error: 0.0173 - val_loss: 0.0196 - val_mean_squared_error: 0.0196
# Epoch 40/500
# 71/73 [============================>.] - ETA: 0s - loss: 0.0163 - mean_squared_error: 0.0163
# Epoch 40: val_loss did not improve from 0.00749
# 73/73 [==============================] - 1s 17ms/step - loss: 0.0163 - mean_squared_error: 0.0163 - val_loss: 0.0976 - val_mean_squared_error: 0.0976
# Epoch 41/500
# 73/73 [==============================] - ETA: 0s - loss: 0.0170 - mean_squared_error: 0.0170
# Epoch 41: val_loss did not improve from 0.00749
# 73/73 [==============================] - 1s 15ms/step - loss: 0.0170 - mean_squared_error: 0.0170 - val_loss: 0.0089 - val_mean_squared_error: 0.0089
# Epoch 42/500
# 70/73 [===========================>..] - ETA: 0s - loss: 0.0233 - mean_squared_error: 0.0233
# Epoch 42: val_loss did not improve from 0.00749
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0231 - mean_squared_error: 0.0231 - val_loss: 0.0093 - val_mean_squared_error: 0.0093
# Epoch 43/500
# 70/73 [===========================>..] - ETA: 0s - loss: 0.0180 - mean_squared_error: 0.0180
# Epoch 43: val_loss did not improve from 0.00749
# 73/73 [==============================] - 1s 15ms/step - loss: 0.0181 - mean_squared_error: 0.0181 - val_loss: 0.0106 - val_mean_squared_error: 0.0106
# Epoch 44/500
# 71/73 [============================>.] - ETA: 0s - loss: 0.0183 - mean_squared_error: 0.0183
# Epoch 44: val_loss did not improve from 0.00749
# 73/73 [==============================] - 1s 16ms/step - loss: 0.0182 - mean_squared_error: 0.0182 - val_loss: 0.0659 - val_mean_squared_error: 0.0659
# Epoch 45/500
# 72/73 [============================>.] - ETA: 0s - loss: 0.0164 - mean_squared_error: 0.0164
# Epoch 45: val_loss did not improve from 0.00749
# 73/73 [==============================] - 1s 17ms/step - loss: 0.0164 - mean_squared_error: 0.0164 - val_loss: 0.0421 - val_mean_squared_error: 0.0421
# Epoch 46/500
# 73/73 [==============================] - ETA: 0s - loss: 0.0163 - mean_squared_error: 0.0163
# Epoch 46: val_loss did not improve from 0.00749
# 73/73 [==============================] - 1s 14ms/step - loss: 0.0163 - mean_squared_error: 0.0163 - val_loss: 0.0459 - val_mean_squared_error: 0.0459
# Epoch 47/500
# 73/73 [==============================] - ETA: 0s - loss: 0.0173 - mean_squared_error: 0.0173
# Epoch 47: val_loss did not improve from 0.00749
# 73/73 [==============================] - 1s 13ms/step - loss: 0.0173 - mean_squared_error: 0.0173 - val_loss: 0.0228 - val_mean_squared_error: 0.0228
# Epoch 48/500
# 73/73 [==============================] - ETA: 0s - loss: 0.0188 - mean_squared_error: 0.0188
# Epoch 48: val_loss did not improve from 0.00749
# 73/73 [==============================] - 1s 17ms/step - loss: 0.0188 - mean_squared_error: 0.0188 - val_loss: 0.0899 - val_mean_squared_error: 0.0899
# Epoch 49/500
# 73/73 [==============================] - ETA: 0s - loss: 0.0178 - mean_squared_error: 0.0178
# Epoch 49: val_loss did not improve from 0.00749
# 73/73 [==============================] - 1s 18ms/step - loss: 0.0178 - mean_squared_error: 0.0178 - val_loss: 0.0664 - val_mean_squared_error: 0.0664
# Epoch 50/500
# 71/73 [============================>.] - ETA: 0s - loss: 0.0186 - mean_squared_error: 0.0186
# Epoch 50: val_loss did not improve from 0.00749
# 73/73 [==============================] - 1s 12ms/step - loss: 0.0186 - mean_squared_error: 0.0186 - val_loss: 0.0368 - val_mean_squared_error: 0.0368
# Epoch 51/500
# 70/73 [===========================>..] - ETA: 0s - loss: 0.0163 - mean_squared_error: 0.0163
# Epoch 51: val_loss did not improve from 0.00749
# 73/73 [==============================] - 1s 12ms/step - loss: 0.0163 - mean_squared_error: 0.0163 - val_loss: 0.0432 - val_mean_squared_error: 0.0432
# Epoch 52/500
# 72/73 [============================>.] - ETA: 0s - loss: 0.0169 - mean_squared_error: 0.0169
# Epoch 52: val_loss did not improve from 0.00749
# 73/73 [==============================] - 1s 11ms/step - loss: 0.0168 - mean_squared_error: 0.0168 - val_loss: 0.0345 - val_mean_squared_error: 0.0345
# Epoch 53/500
# 69/73 [===========================>..] - ETA: 0s - loss: 0.0178 - mean_squared_error: 0.0178
# Epoch 53: val_loss improved from 0.00749 to 0.00722, saving model to ./drive/MyDrive/TCC/single_lstm_regression8/best_model_earlyStop.hdf5
# 73/73 [==============================] - 1s 15ms/step - loss: 0.0175 - mean_squared_error: 0.0175 - val_loss: 0.0072 - val_mean_squared_error: 0.0072
# Epoch 54/500
# 71/73 [============================>.] - ETA: 0s - loss: 0.0178 - mean_squared_error: 0.0178
# Epoch 54: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0177 - mean_squared_error: 0.0177 - val_loss: 0.2111 - val_mean_squared_error: 0.2111
# Epoch 55/500
# 69/73 [===========================>..] - ETA: 0s - loss: 0.0167 - mean_squared_error: 0.0167
# Epoch 55: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 8ms/step - loss: 0.0166 - mean_squared_error: 0.0166 - val_loss: 0.0803 - val_mean_squared_error: 0.0803
# Epoch 56/500
# 69/73 [===========================>..] - ETA: 0s - loss: 0.0182 - mean_squared_error: 0.0182
# Epoch 56: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 8ms/step - loss: 0.0179 - mean_squared_error: 0.0179 - val_loss: 0.0507 - val_mean_squared_error: 0.0507
# Epoch 57/500
# 69/73 [===========================>..] - ETA: 0s - loss: 0.0199 - mean_squared_error: 0.0199
# Epoch 57: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 8ms/step - loss: 0.0198 - mean_squared_error: 0.0198 - val_loss: 0.1444 - val_mean_squared_error: 0.1444
# Epoch 58/500
# 69/73 [===========================>..] - ETA: 0s - loss: 0.0179 - mean_squared_error: 0.0179
# Epoch 58: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 9ms/step - loss: 0.0177 - mean_squared_error: 0.0177 - val_loss: 0.2459 - val_mean_squared_error: 0.2459
# Epoch 59/500
# 67/73 [==========================>...] - ETA: 0s - loss: 0.0182 - mean_squared_error: 0.0182
# Epoch 59: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 8ms/step - loss: 0.0181 - mean_squared_error: 0.0181 - val_loss: 0.0209 - val_mean_squared_error: 0.0209
# Epoch 60/500
# 73/73 [==============================] - ETA: 0s - loss: 0.0171 - mean_squared_error: 0.0171
# Epoch 60: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 8ms/step - loss: 0.0171 - mean_squared_error: 0.0171 - val_loss: 0.2408 - val_mean_squared_error: 0.2408
# Epoch 61/500
# 72/73 [============================>.] - ETA: 0s - loss: 0.0193 - mean_squared_error: 0.0193
# Epoch 61: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 9ms/step - loss: 0.0194 - mean_squared_error: 0.0194 - val_loss: 0.3378 - val_mean_squared_error: 0.3378
# Epoch 62/500
# 69/73 [===========================>..] - ETA: 0s - loss: 0.0192 - mean_squared_error: 0.0192
# Epoch 62: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 8ms/step - loss: 0.0191 - mean_squared_error: 0.0191 - val_loss: 0.0538 - val_mean_squared_error: 0.0538
# Epoch 63/500
# 67/73 [==========================>...] - ETA: 0s - loss: 0.0178 - mean_squared_error: 0.0178
# Epoch 63: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 9ms/step - loss: 0.0181 - mean_squared_error: 0.0181 - val_loss: 0.0091 - val_mean_squared_error: 0.0091
# Epoch 64/500
# 69/73 [===========================>..] - ETA: 0s - loss: 0.0190 - mean_squared_error: 0.0190
# Epoch 64: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 8ms/step - loss: 0.0188 - mean_squared_error: 0.0188 - val_loss: 0.0106 - val_mean_squared_error: 0.0106
# Epoch 65/500
# 71/73 [============================>.] - ETA: 0s - loss: 0.0162 - mean_squared_error: 0.0162
# Epoch 65: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 8ms/step - loss: 0.0161 - mean_squared_error: 0.0161 - val_loss: 0.0515 - val_mean_squared_error: 0.0515
# Epoch 66/500
# 70/73 [===========================>..] - ETA: 0s - loss: 0.0158 - mean_squared_error: 0.0158
# Epoch 66: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 8ms/step - loss: 0.0157 - mean_squared_error: 0.0157 - val_loss: 0.0259 - val_mean_squared_error: 0.0259
# Epoch 67/500
# 69/73 [===========================>..] - ETA: 0s - loss: 0.0149 - mean_squared_error: 0.0149
# Epoch 67: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 8ms/step - loss: 0.0148 - mean_squared_error: 0.0148 - val_loss: 0.0268 - val_mean_squared_error: 0.0268
# Epoch 68/500
# 71/73 [============================>.] - ETA: 0s - loss: 0.0167 - mean_squared_error: 0.0167
# Epoch 68: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 8ms/step - loss: 0.0167 - mean_squared_error: 0.0167 - val_loss: 0.0812 - val_mean_squared_error: 0.0812
# Epoch 69/500
# 72/73 [============================>.] - ETA: 0s - loss: 0.0179 - mean_squared_error: 0.0179
# Epoch 69: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 9ms/step - loss: 0.0179 - mean_squared_error: 0.0179 - val_loss: 0.2670 - val_mean_squared_error: 0.2670
# Epoch 70/500
# 70/73 [===========================>..] - ETA: 0s - loss: 0.0160 - mean_squared_error: 0.0160
# Epoch 70: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 12ms/step - loss: 0.0161 - mean_squared_error: 0.0161 - val_loss: 0.0494 - val_mean_squared_error: 0.0494
# Epoch 71/500
# 71/73 [============================>.] - ETA: 0s - loss: 0.0192 - mean_squared_error: 0.0192
# Epoch 71: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 11ms/step - loss: 0.0191 - mean_squared_error: 0.0191 - val_loss: 0.0367 - val_mean_squared_error: 0.0367
# Epoch 72/500
# 71/73 [============================>.] - ETA: 0s - loss: 0.0160 - mean_squared_error: 0.0160
# Epoch 72: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 12ms/step - loss: 0.0162 - mean_squared_error: 0.0162 - val_loss: 0.0219 - val_mean_squared_error: 0.0219
# Epoch 73/500
# 70/73 [===========================>..] - ETA: 0s - loss: 0.0152 - mean_squared_error: 0.0152
# Epoch 73: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 14ms/step - loss: 0.0152 - mean_squared_error: 0.0152 - val_loss: 0.0293 - val_mean_squared_error: 0.0293
# Epoch 74/500
# 72/73 [============================>.] - ETA: 0s - loss: 0.0155 - mean_squared_error: 0.0155
# Epoch 74: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 14ms/step - loss: 0.0156 - mean_squared_error: 0.0156 - val_loss: 0.0156 - val_mean_squared_error: 0.0156
# Epoch 75/500
# 71/73 [============================>.] - ETA: 0s - loss: 0.0168 - mean_squared_error: 0.0168
# Epoch 75: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 13ms/step - loss: 0.0167 - mean_squared_error: 0.0167 - val_loss: 0.0733 - val_mean_squared_error: 0.0733
# Epoch 76/500
# 71/73 [============================>.] - ETA: 0s - loss: 0.0166 - mean_squared_error: 0.0166
# Epoch 76: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 17ms/step - loss: 0.0166 - mean_squared_error: 0.0166 - val_loss: 0.0827 - val_mean_squared_error: 0.0827
# Epoch 77/500
# 72/73 [============================>.] - ETA: 0s - loss: 0.0160 - mean_squared_error: 0.0160
# Epoch 77: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 14ms/step - loss: 0.0159 - mean_squared_error: 0.0159 - val_loss: 0.0119 - val_mean_squared_error: 0.0119
# Epoch 78/500
# 69/73 [===========================>..] - ETA: 0s - loss: 0.0167 - mean_squared_error: 0.0167
# Epoch 78: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 12ms/step - loss: 0.0167 - mean_squared_error: 0.0167 - val_loss: 0.0209 - val_mean_squared_error: 0.0209
# Epoch 79/500
# 70/73 [===========================>..] - ETA: 0s - loss: 0.0154 - mean_squared_error: 0.0154
# Epoch 79: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 12ms/step - loss: 0.0155 - mean_squared_error: 0.0155 - val_loss: 0.0424 - val_mean_squared_error: 0.0424
# Epoch 80/500
# 69/73 [===========================>..] - ETA: 0s - loss: 0.0148 - mean_squared_error: 0.0148
# Epoch 80: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 12ms/step - loss: 0.0148 - mean_squared_error: 0.0148 - val_loss: 0.0135 - val_mean_squared_error: 0.0135
# Epoch 81/500
# 69/73 [===========================>..] - ETA: 0s - loss: 0.0158 - mean_squared_error: 0.0158
# Epoch 81: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 9ms/step - loss: 0.0158 - mean_squared_error: 0.0158 - val_loss: 0.0416 - val_mean_squared_error: 0.0416
# Epoch 82/500
# 66/73 [==========================>...] - ETA: 0s - loss: 0.0176 - mean_squared_error: 0.0176
# Epoch 82: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 8ms/step - loss: 0.0175 - mean_squared_error: 0.0175 - val_loss: 0.0768 - val_mean_squared_error: 0.0768
# Epoch 83/500
# 72/73 [============================>.] - ETA: 0s - loss: 0.0188 - mean_squared_error: 0.0188
# Epoch 83: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 8ms/step - loss: 0.0188 - mean_squared_error: 0.0188 - val_loss: 0.0823 - val_mean_squared_error: 0.0823
# Epoch 84/500
# 71/73 [============================>.] - ETA: 0s - loss: 0.0452 - mean_squared_error: 0.0452
# Epoch 84: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 8ms/step - loss: 0.0448 - mean_squared_error: 0.0448 - val_loss: 0.0078 - val_mean_squared_error: 0.0078
# Epoch 85/500
# 70/73 [===========================>..] - ETA: 0s - loss: 0.0200 - mean_squared_error: 0.0200
# Epoch 85: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 9ms/step - loss: 0.0198 - mean_squared_error: 0.0198 - val_loss: 0.0134 - val_mean_squared_error: 0.0134
# Epoch 86/500
# 70/73 [===========================>..] - ETA: 0s - loss: 0.0201 - mean_squared_error: 0.0201
# Epoch 86: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 9ms/step - loss: 0.0200 - mean_squared_error: 0.0200 - val_loss: 0.2452 - val_mean_squared_error: 0.2452
# Epoch 87/500
# 67/73 [==========================>...] - ETA: 0s - loss: 0.0184 - mean_squared_error: 0.0184
# Epoch 87: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 9ms/step - loss: 0.0184 - mean_squared_error: 0.0184 - val_loss: 0.0110 - val_mean_squared_error: 0.0110
# Epoch 88/500
# 71/73 [============================>.] - ETA: 0s - loss: 0.0172 - mean_squared_error: 0.0172
# Epoch 88: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 9ms/step - loss: 0.0172 - mean_squared_error: 0.0172 - val_loss: 0.0344 - val_mean_squared_error: 0.0344
# Epoch 89/500
# 70/73 [===========================>..] - ETA: 0s - loss: 0.0164 - mean_squared_error: 0.0164
# Epoch 89: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 8ms/step - loss: 0.0164 - mean_squared_error: 0.0164 - val_loss: 0.0874 - val_mean_squared_error: 0.0874
# Epoch 90/500
# 68/73 [==========================>...] - ETA: 0s - loss: 0.0171 - mean_squared_error: 0.0171
# Epoch 90: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 9ms/step - loss: 0.0169 - mean_squared_error: 0.0169 - val_loss: 0.0714 - val_mean_squared_error: 0.0714
# Epoch 91/500
# 73/73 [==============================] - ETA: 0s - loss: 0.0157 - mean_squared_error: 0.0157
# Epoch 91: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 9ms/step - loss: 0.0157 - mean_squared_error: 0.0157 - val_loss: 0.0499 - val_mean_squared_error: 0.0499
# Epoch 92/500
# 70/73 [===========================>..] - ETA: 0s - loss: 0.0162 - mean_squared_error: 0.0162
# Epoch 92: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 12ms/step - loss: 0.0163 - mean_squared_error: 0.0163 - val_loss: 0.0403 - val_mean_squared_error: 0.0403
# Epoch 93/500
# 69/73 [===========================>..] - ETA: 0s - loss: 0.0175 - mean_squared_error: 0.0175
# Epoch 93: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 13ms/step - loss: 0.0174 - mean_squared_error: 0.0174 - val_loss: 0.0298 - val_mean_squared_error: 0.0298
# Epoch 94/500
# 69/73 [===========================>..] - ETA: 0s - loss: 0.0152 - mean_squared_error: 0.0152
# Epoch 94: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 12ms/step - loss: 0.0150 - mean_squared_error: 0.0150 - val_loss: 0.0653 - val_mean_squared_error: 0.0653
# Epoch 95/500
# 70/73 [===========================>..] - ETA: 0s - loss: 0.0155 - mean_squared_error: 0.0155
# Epoch 95: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 12ms/step - loss: 0.0154 - mean_squared_error: 0.0154 - val_loss: 0.0601 - val_mean_squared_error: 0.0601
# Epoch 96/500
# 73/73 [==============================] - ETA: 0s - loss: 0.0158 - mean_squared_error: 0.0158
# Epoch 96: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 13ms/step - loss: 0.0158 - mean_squared_error: 0.0158 - val_loss: 0.0187 - val_mean_squared_error: 0.0187
# Epoch 97/500
# 70/73 [===========================>..] - ETA: 0s - loss: 0.0157 - mean_squared_error: 0.0157
# Epoch 97: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 12ms/step - loss: 0.0158 - mean_squared_error: 0.0158 - val_loss: 0.0622 - val_mean_squared_error: 0.0622
# Epoch 98/500
# 68/73 [==========================>...] - ETA: 0s - loss: 0.0160 - mean_squared_error: 0.0160
# Epoch 98: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 11ms/step - loss: 0.0160 - mean_squared_error: 0.0160 - val_loss: 0.0478 - val_mean_squared_error: 0.0478
# Epoch 99/500
# 70/73 [===========================>..] - ETA: 0s - loss: 0.0151 - mean_squared_error: 0.0151
# Epoch 99: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0150 - mean_squared_error: 0.0150 - val_loss: 0.0126 - val_mean_squared_error: 0.0126
# Epoch 100/500
# 72/73 [============================>.] - ETA: 0s - loss: 0.0152 - mean_squared_error: 0.0152
# Epoch 100: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 9ms/step - loss: 0.0151 - mean_squared_error: 0.0151 - val_loss: 0.0209 - val_mean_squared_error: 0.0209
# Epoch 101/500
# 70/73 [===========================>..] - ETA: 0s - loss: 0.0165 - mean_squared_error: 0.0165
# Epoch 101: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 8ms/step - loss: 0.0165 - mean_squared_error: 0.0165 - val_loss: 0.0832 - val_mean_squared_error: 0.0832
# Epoch 102/500
# 70/73 [===========================>..] - ETA: 0s - loss: 0.0157 - mean_squared_error: 0.0157
# Epoch 102: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0157 - mean_squared_error: 0.0157 - val_loss: 0.0250 - val_mean_squared_error: 0.0250
# Epoch 103/500
# 73/73 [==============================] - ETA: 0s - loss: 0.0185 - mean_squared_error: 0.0185
# Epoch 103: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 9ms/step - loss: 0.0185 - mean_squared_error: 0.0185 - val_loss: 0.0582 - val_mean_squared_error: 0.0582
# Epoch 104/500
# 68/73 [==========================>...] - ETA: 0s - loss: 0.0227 - mean_squared_error: 0.0227
# Epoch 104: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 8ms/step - loss: 0.0229 - mean_squared_error: 0.0229 - val_loss: 0.0196 - val_mean_squared_error: 0.0196
# Epoch 105/500
# 73/73 [==============================] - ETA: 0s - loss: 0.0172 - mean_squared_error: 0.0172
# Epoch 105: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 9ms/step - loss: 0.0172 - mean_squared_error: 0.0172 - val_loss: 0.0849 - val_mean_squared_error: 0.0849
# Epoch 106/500
# 73/73 [==============================] - ETA: 0s - loss: 0.0162 - mean_squared_error: 0.0162
# Epoch 106: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 8ms/step - loss: 0.0162 - mean_squared_error: 0.0162 - val_loss: 0.0684 - val_mean_squared_error: 0.0684
# Epoch 107/500
# 66/73 [==========================>...] - ETA: 0s - loss: 0.0186 - mean_squared_error: 0.0186
# Epoch 107: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 8ms/step - loss: 0.0187 - mean_squared_error: 0.0187 - val_loss: 0.0328 - val_mean_squared_error: 0.0328
# Epoch 108/500
# 72/73 [============================>.] - ETA: 0s - loss: 0.0170 - mean_squared_error: 0.0170
# Epoch 108: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0170 - mean_squared_error: 0.0170 - val_loss: 0.0336 - val_mean_squared_error: 0.0336
# Epoch 109/500
# 71/73 [============================>.] - ETA: 0s - loss: 0.0166 - mean_squared_error: 0.0166
# Epoch 109: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0167 - mean_squared_error: 0.0167 - val_loss: 0.1077 - val_mean_squared_error: 0.1077
# Epoch 110/500
# 71/73 [============================>.] - ETA: 0s - loss: 0.0154 - mean_squared_error: 0.0154
# Epoch 110: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0155 - mean_squared_error: 0.0155 - val_loss: 0.0319 - val_mean_squared_error: 0.0319
# Epoch 111/500
# 69/73 [===========================>..] - ETA: 0s - loss: 0.0166 - mean_squared_error: 0.0166
# Epoch 111: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 9ms/step - loss: 0.0164 - mean_squared_error: 0.0164 - val_loss: 0.0930 - val_mean_squared_error: 0.0930
# Epoch 112/500
# 69/73 [===========================>..] - ETA: 0s - loss: 0.0158 - mean_squared_error: 0.0158
# Epoch 112: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 9ms/step - loss: 0.0160 - mean_squared_error: 0.0160 - val_loss: 0.0198 - val_mean_squared_error: 0.0198
# Epoch 113/500
# 72/73 [============================>.] - ETA: 0s - loss: 0.0166 - mean_squared_error: 0.0166
# Epoch 113: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 11ms/step - loss: 0.0166 - mean_squared_error: 0.0166 - val_loss: 0.0910 - val_mean_squared_error: 0.0910
# Epoch 114/500
# 70/73 [===========================>..] - ETA: 0s - loss: 0.0149 - mean_squared_error: 0.0149
# Epoch 114: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 12ms/step - loss: 0.0149 - mean_squared_error: 0.0149 - val_loss: 0.0350 - val_mean_squared_error: 0.0350
# Epoch 115/500
# 73/73 [==============================] - ETA: 0s - loss: 0.0166 - mean_squared_error: 0.0166
# Epoch 115: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 13ms/step - loss: 0.0166 - mean_squared_error: 0.0166 - val_loss: 0.0632 - val_mean_squared_error: 0.0632
# Epoch 116/500
# 71/73 [============================>.] - ETA: 0s - loss: 0.0166 - mean_squared_error: 0.0166
# Epoch 116: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 13ms/step - loss: 0.0165 - mean_squared_error: 0.0165 - val_loss: 0.0817 - val_mean_squared_error: 0.0817
# Epoch 117/500
# 71/73 [============================>.] - ETA: 0s - loss: 0.0168 - mean_squared_error: 0.0168
# Epoch 117: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 12ms/step - loss: 0.0168 - mean_squared_error: 0.0168 - val_loss: 0.2294 - val_mean_squared_error: 0.2294
# Epoch 118/500
# 70/73 [===========================>..] - ETA: 0s - loss: 0.0184 - mean_squared_error: 0.0184
# Epoch 118: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 12ms/step - loss: 0.0184 - mean_squared_error: 0.0184 - val_loss: 0.1228 - val_mean_squared_error: 0.1228
# Epoch 119/500
# 72/73 [============================>.] - ETA: 0s - loss: 0.0181 - mean_squared_error: 0.0181
# Epoch 119: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 11ms/step - loss: 0.0181 - mean_squared_error: 0.0181 - val_loss: 0.1294 - val_mean_squared_error: 0.1294
# Epoch 120/500
# 69/73 [===========================>..] - ETA: 0s - loss: 0.0161 - mean_squared_error: 0.0161
# Epoch 120: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 9ms/step - loss: 0.0161 - mean_squared_error: 0.0161 - val_loss: 0.1039 - val_mean_squared_error: 0.1039
# Epoch 121/500
# 72/73 [============================>.] - ETA: 0s - loss: 0.0161 - mean_squared_error: 0.0161
# Epoch 121: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 8ms/step - loss: 0.0161 - mean_squared_error: 0.0161 - val_loss: 0.0550 - val_mean_squared_error: 0.0550
# Epoch 122/500
# 71/73 [============================>.] - ETA: 0s - loss: 0.0151 - mean_squared_error: 0.0151
# Epoch 122: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0151 - mean_squared_error: 0.0151 - val_loss: 0.0491 - val_mean_squared_error: 0.0491
# Epoch 123/500
# 70/73 [===========================>..] - ETA: 0s - loss: 0.0170 - mean_squared_error: 0.0170
# Epoch 123: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0169 - mean_squared_error: 0.0169 - val_loss: 0.0409 - val_mean_squared_error: 0.0409
# Epoch 124/500
# 67/73 [==========================>...] - ETA: 0s - loss: 0.0190 - mean_squared_error: 0.0190
# Epoch 124: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 9ms/step - loss: 0.0189 - mean_squared_error: 0.0189 - val_loss: 0.0604 - val_mean_squared_error: 0.0604
# Epoch 125/500
# 71/73 [============================>.] - ETA: 0s - loss: 0.0156 - mean_squared_error: 0.0156
# Epoch 125: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0155 - mean_squared_error: 0.0155 - val_loss: 0.0680 - val_mean_squared_error: 0.0680
# Epoch 126/500
# 67/73 [==========================>...] - ETA: 0s - loss: 0.0159 - mean_squared_error: 0.0159
# Epoch 126: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 9ms/step - loss: 0.0157 - mean_squared_error: 0.0157 - val_loss: 0.0355 - val_mean_squared_error: 0.0355
# Epoch 127/500
# 69/73 [===========================>..] - ETA: 0s - loss: 0.0156 - mean_squared_error: 0.0156
# Epoch 127: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 8ms/step - loss: 0.0156 - mean_squared_error: 0.0156 - val_loss: 0.0697 - val_mean_squared_error: 0.0697
# Epoch 128/500
# 66/73 [==========================>...] - ETA: 0s - loss: 0.0181 - mean_squared_error: 0.0181
# Epoch 128: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 8ms/step - loss: 0.0177 - mean_squared_error: 0.0177 - val_loss: 0.0237 - val_mean_squared_error: 0.0237
# Epoch 129/500
# 73/73 [==============================] - ETA: 0s - loss: 0.0147 - mean_squared_error: 0.0147
# Epoch 129: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 9ms/step - loss: 0.0147 - mean_squared_error: 0.0147 - val_loss: 0.0971 - val_mean_squared_error: 0.0971
# Epoch 130/500
# 67/73 [==========================>...] - ETA: 0s - loss: 0.0156 - mean_squared_error: 0.0156
# Epoch 130: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 9ms/step - loss: 0.0156 - mean_squared_error: 0.0156 - val_loss: 0.0290 - val_mean_squared_error: 0.0290
# Epoch 131/500
# 73/73 [==============================] - ETA: 0s - loss: 0.0199 - mean_squared_error: 0.0199
# Epoch 131: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 9ms/step - loss: 0.0199 - mean_squared_error: 0.0199 - val_loss: 0.0868 - val_mean_squared_error: 0.0868
# Epoch 132/500
# 67/73 [==========================>...] - ETA: 0s - loss: 0.0171 - mean_squared_error: 0.0171
# Epoch 132: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 8ms/step - loss: 0.0170 - mean_squared_error: 0.0170 - val_loss: 0.1015 - val_mean_squared_error: 0.1015
# Epoch 133/500
# 68/73 [==========================>...] - ETA: 0s - loss: 0.0177 - mean_squared_error: 0.0177
# Epoch 133: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 9ms/step - loss: 0.0178 - mean_squared_error: 0.0178 - val_loss: 0.1331 - val_mean_squared_error: 0.1331
# Epoch 134/500
# 67/73 [==========================>...] - ETA: 0s - loss: 0.0178 - mean_squared_error: 0.0178
# Epoch 134: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 9ms/step - loss: 0.0177 - mean_squared_error: 0.0177 - val_loss: 0.0790 - val_mean_squared_error: 0.0790
# Epoch 135/500
# 71/73 [============================>.] - ETA: 0s - loss: 0.0169 - mean_squared_error: 0.0169
# Epoch 135: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 12ms/step - loss: 0.0169 - mean_squared_error: 0.0169 - val_loss: 0.0472 - val_mean_squared_error: 0.0472
# Epoch 136/500
# 72/73 [============================>.] - ETA: 0s - loss: 0.0174 - mean_squared_error: 0.0174
# Epoch 136: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 11ms/step - loss: 0.0175 - mean_squared_error: 0.0175 - val_loss: 0.2035 - val_mean_squared_error: 0.2035
# Epoch 137/500
# 69/73 [===========================>..] - ETA: 0s - loss: 0.0185 - mean_squared_error: 0.0185
# Epoch 137: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 12ms/step - loss: 0.0186 - mean_squared_error: 0.0186 - val_loss: 0.1294 - val_mean_squared_error: 0.1294
# Epoch 138/500
# 72/73 [============================>.] - ETA: 0s - loss: 0.0155 - mean_squared_error: 0.0155
# Epoch 138: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 13ms/step - loss: 0.0155 - mean_squared_error: 0.0155 - val_loss: 0.1448 - val_mean_squared_error: 0.1448
# Epoch 139/500
# 68/73 [==========================>...] - ETA: 0s - loss: 0.0151 - mean_squared_error: 0.0151
# Epoch 139: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 12ms/step - loss: 0.0153 - mean_squared_error: 0.0153 - val_loss: 0.0615 - val_mean_squared_error: 0.0615
# Epoch 140/500
# 71/73 [============================>.] - ETA: 0s - loss: 0.0148 - mean_squared_error: 0.0148
# Epoch 140: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 13ms/step - loss: 0.0148 - mean_squared_error: 0.0148 - val_loss: 0.0210 - val_mean_squared_error: 0.0210
# Epoch 141/500
# 70/73 [===========================>..] - ETA: 0s - loss: 0.0141 - mean_squared_error: 0.0141
# Epoch 141: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 13ms/step - loss: 0.0141 - mean_squared_error: 0.0141 - val_loss: 0.0431 - val_mean_squared_error: 0.0431
# Epoch 142/500
# 70/73 [===========================>..] - ETA: 0s - loss: 0.0180 - mean_squared_error: 0.0180
# Epoch 142: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0180 - mean_squared_error: 0.0180 - val_loss: 0.0411 - val_mean_squared_error: 0.0411
# Epoch 143/500
# 73/73 [==============================] - ETA: 0s - loss: 0.0173 - mean_squared_error: 0.0173
# Epoch 143: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 8ms/step - loss: 0.0173 - mean_squared_error: 0.0173 - val_loss: 0.0267 - val_mean_squared_error: 0.0267
# Epoch 144/500
# 72/73 [============================>.] - ETA: 0s - loss: 0.0157 - mean_squared_error: 0.0157
# Epoch 144: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 9ms/step - loss: 0.0158 - mean_squared_error: 0.0158 - val_loss: 0.0532 - val_mean_squared_error: 0.0532
# Epoch 145/500
# 69/73 [===========================>..] - ETA: 0s - loss: 0.0210 - mean_squared_error: 0.0210
# Epoch 145: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0206 - mean_squared_error: 0.0206 - val_loss: 0.0385 - val_mean_squared_error: 0.0385
# Epoch 146/500
# 73/73 [==============================] - ETA: 0s - loss: 0.0168 - mean_squared_error: 0.0168
# Epoch 146: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 9ms/step - loss: 0.0168 - mean_squared_error: 0.0168 - val_loss: 0.0545 - val_mean_squared_error: 0.0545
# Epoch 147/500
# 70/73 [===========================>..] - ETA: 0s - loss: 0.0169 - mean_squared_error: 0.0169
# Epoch 147: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 9ms/step - loss: 0.0170 - mean_squared_error: 0.0170 - val_loss: 0.1473 - val_mean_squared_error: 0.1473
# Epoch 148/500
# 72/73 [============================>.] - ETA: 0s - loss: 0.0186 - mean_squared_error: 0.0186
# Epoch 148: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 8ms/step - loss: 0.0186 - mean_squared_error: 0.0186 - val_loss: 0.1413 - val_mean_squared_error: 0.1413
# Epoch 149/500
# 73/73 [==============================] - ETA: 0s - loss: 0.0165 - mean_squared_error: 0.0165
# Epoch 149: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0165 - mean_squared_error: 0.0165 - val_loss: 0.0235 - val_mean_squared_error: 0.0235
# Epoch 150/500
# 72/73 [============================>.] - ETA: 0s - loss: 0.0163 - mean_squared_error: 0.0163
# Epoch 150: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0163 - mean_squared_error: 0.0163 - val_loss: 0.0318 - val_mean_squared_error: 0.0318
# Epoch 151/500
# 69/73 [===========================>..] - ETA: 0s - loss: 0.0174 - mean_squared_error: 0.0174
# Epoch 151: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0173 - mean_squared_error: 0.0173 - val_loss: 0.0603 - val_mean_squared_error: 0.0603
# Epoch 152/500
# 70/73 [===========================>..] - ETA: 0s - loss: 0.0194 - mean_squared_error: 0.0194
# Epoch 152: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 10ms/step - loss: 0.0193 - mean_squared_error: 0.0193 - val_loss: 0.1256 - val_mean_squared_error: 0.1256
# Epoch 153/500
# 70/73 [===========================>..] - ETA: 0s - loss: 0.0153 - mean_squared_error: 0.0153
# Epoch 153: val_loss did not improve from 0.00722
# 73/73 [==============================] - 1s 9ms/step - loss: 0.0154 - mean_squared_error: 0.0154 - val_loss: 0.0410 - val_mean_squared_error: 0.0410

# %% [markdown]
# ## Resultados

# %% [markdown]
# Gráfico de Perda por Época

# %%
checkpoint_path = PATH + 'best_model_earlyStop.hdf5'
loaded_model = load_model(checkpoint_path)
output_file = open(PATH + "saida.txt", "w")

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))

# ax1.plot(history.history['r_square'])
# ax1.plot(history.history['val_r_square'])
# ax1.set_title('Model r_square')
# ax1.set_ylabel('r_square')
# ax1.set_xlabel('Epoch')
# ax1.legend(['Train', 'Validation'], loc='upper left')


ax2.plot(history.history['loss'])
ax2.plot(history.history['val_loss'])
ax2.set_title('Model Loss = Mean Squared Error')
ax2.set_ylabel('Loss')
ax2.set_xlabel('Epoch')
ax2.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# Métricas de Desempenho

# %%
y_train_predict_log = loaded_model.predict(x_train)

y_val_predict_log = loaded_model.predict(x_val)

y_test_predict_log = loaded_model.predict(x_test)

def printResults(expected, result):
  mse = mean_squared_error(expected, result)
  rmse = np.sqrt(mse)
  mae = mean_absolute_error(expected, result)
  r2 = r2_score(expected, result)
  mape = np.mean(np.abs((expected - result) / expected)) * 100
  print(f"MAE: {mae}")
  print(f"MSE: {mse}")
  print(f"RMSE: {rmse}")
  print(f"MAPE: {mape}%")
  print(f"R²: {r2}")

print('----- Métricas de Regressão -----')
print('------------- Train -------------')
printResults(y_train, y_train_predict_log)
print('---------- Validation -----------')
printResults(y_val, y_val_predict_log)
print('-------------- Test -------------')
printResults(y_test, y_test_predict_log)
print()
# Out:
# 73/73 [==============================] - 1s 5ms/step
# 11/11 [==============================] - 0s 7ms/step
# 21/21 [==============================] - 0s 6ms/step
# ----- Métricas de Regressão -----
# ------------- Train -------------
# MAE: 0.07655119718668545
# MSE: 0.010339880742127414
# RMSE: 0.10168520414557575
# MAPE: 2.2925001258525057%
# R²: 0.9757741579285839
# ---------- Validation -----------
# MAE: 0.08073933810224941
# MSE: 0.00905810064941474
# RMSE: 0.09517405449708834
# MAPE: 1.7224088182564867%
# R²: -0.2023118066893319
# -------------- Test -------------
# MAE: 0.0684951998713113
# MSE: 0.0074745942899443005
# RMSE: 0.08645573601528299
# MAPE: 1.5627647565246383%
# R²: 0.47207655719066055

# %% [markdown]
# ## Transformar Regressão e Classes

# %%
print("Target Class Threshold: 3")
class_counts = target_df_Class3['YClass'].value_counts().sort_index()
print(class_counts)
print()

print("Target Class Threshold: 5")
class_counts = target_df_Class5['YClass'].value_counts().sort_index()
print(class_counts)
print()

print("Target Class Threshold: 7")
class_counts = target_df_Class7['YClass'].value_counts().sort_index()
print(class_counts)
print()
print()
# Out:
# Target Class Threshold: 3
# 0    1204
# 1     444
# 2    1648
# Name: YClass, dtype: int64
#
# Target Class Threshold: 5
# 0    1044
# 1     743
# 2    1509
# Name: YClass, dtype: int64
#
# Target Class Threshold: 7
# 0     927
# 1    1016
# 2    1353
# Name: YClass, dtype: int64

# %%
# y_test_predict = valor predito
# y_test = preço real
# y_test_class = a classe da variação percentual real
# y_test_variation = a variação percentual real
# Para prever o percentual predito, é necessário encontrar o valor real anterior
# Para isso, deve-se usar o valor real e a variação real. Variação = (V_final - V_inicial)/V_inicial

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt
def printClassificationResults(y_test_class):
  y_test_predict = 10 ** y_test_predict_log
  y_test_real = 10 ** y_test
  y_test_class = np.array(y_test_class)

  def defineClass(variation):
    if variation > THRESHOLD:
      return 2
    elif variation < -THRESHOLD:
      return 0
    else:
      return 1
  def find_initial_price(preco_final, variacao_percentual):
    return preco_final / (1 + (variacao_percentual / 100))

  y_test_initial = [find_initial_price(y_test_real[i], np.array(y_test_variation)[i]) for i in range(len(y_test_real))]

  y_test_variation_predict = ((y_test_predict - y_test_initial) / y_test_initial) * 100

  y_test_class_predict = [defineClass(variation) for variation in y_test_variation_predict]


  # Transforme as classes reais e previstas em rótulos binários
  lb = LabelBinarizer()
  y_test_class_bin = lb.fit_transform(y_test_class)
  y_test_class_predict_bin = lb.transform(y_test_class_predict)

  accuracy = accuracy_score(y_test_class, y_test_class_predict)
  # Precisão, Recall e F1-Score (para cada classe)
  precision = precision_score(y_test_class, y_test_class_predict, average=None)
  recall = recall_score(y_test_class, y_test_class_predict, average=None)
  f1 = f1_score(y_test_class, y_test_class_predict, average=None)
  roc_auc = roc_auc_score(y_test_class_bin, y_test_class_predict_bin, average=None)

  average_precision = precision_score(y_test_class, y_test_class_predict, average='micro')
  average_recall = recall_score(y_test_class, y_test_class_predict, average='micro')
  average_f1 = f1_score(y_test_class, y_test_class_predict, average='micro')
  average_auc = roc_auc_score(y_test_class_bin, y_test_class_predict_bin, average='micro')

  print("Métricas por classe:")
  print("Precisão:", precision)
  print("Recall:", recall)
  print("F1-Score:", f1)
  print("AUC Médio:", roc_auc)
  print()
  print("Média das métricas:")
  print("Acurácia:", accuracy)
  print("Precisão:", average_precision)
  print("Recall:", average_recall)
  print("F1-Score:", average_f1)
  print("AUC Médio:", average_auc)
  print()


  def plotROC(y_true, y_score, class_names):
      n_classes = len(class_names)

      # Inicialize a figura do gráfico
      plt.figure(figsize=(8, 6))

      # Defina as cores para as curvas ROC
      colors = ['b', 'g', 'r', 'c', 'm', 'y', 'k']

      # Plote as curvas ROC para cada classe
      for i in range(n_classes):
          fpr, tpr, _ = roc_curve(y_true[:, i], y_score[:, i])
          roc_auc = auc(fpr, tpr)
          plt.plot(fpr, tpr, color=colors[i], lw=2, label=f'Class {class_names[i]} (AUC = {roc_auc:.2f})')

      # Plot the random chance line
      plt.plot([0, 1], [0, 1], 'k--', lw=2, label='Random Chance')

      # Customize the plot
      plt.xlim([0.0, 1.0])
      plt.ylim([0.0, 1.05])
      plt.xlabel('False Positive Rate')
      plt.ylabel('True Positive Rate')
      plt.title('ROC Curves for Multiclass Classification')
      plt.legend(loc='lower right')
      plt.show()

  # Supondo que y_test_class_bin e y_test_class_predict_bin são matrizes com as probabilidades das classes
  class_names = [0, 1, 2]  # Nomes das classes ou rótulos
  plotROC(y_test_class_bin, y_test_class_predict_bin, class_names)

# %%
print('=============================')
print('Métricas para o THRESHOLD = 3')
printClassificationResults(y_test_class3)
# Out:
# =============================
# Métricas para o THRESHOLD = 3
# Métricas por classe:
# Precisão: [0.85294118 0.1443299  0.40642722]
# Recall: [0.09634551 0.11864407 0.89211618]
# F1-Score: [0.17313433 0.13023256 0.55844156]
# AUC Médio: [0.54120897 0.48275377 0.57135642]
#
# Média das métricas:
# Acurácia: 0.39090909090909093
# Precisão: 0.39090909090909093
# Recall: 0.39090909090909093
# F1-Score: 0.39090909090909093
# AUC Médio: 0.5431818181818182

# %%
print('=============================')
print('Métricas para o THRESHOLD = 5')
printClassificationResults(y_test_class5)
# Out:
# =============================
# Métricas para o THRESHOLD = 5
# Métricas por classe:
# Precisão: [0.82352941 0.28865979 0.36672968]
# Recall: [0.1147541  0.13930348 0.90232558]
# F1-Score: [0.20143885 0.18791946 0.52150538]
# AUC Médio: [0.55016551 0.49448834 0.5747583 ]
#
# Média das métricas:
# Acurácia: 0.3787878787878788
# Precisão: 0.3787878787878788
# Recall: 0.3787878787878788
# F1-Score: 0.3787878787878788
# AUC Médio: 0.5340909090909092

# %%
print('=============================')
print('Métricas para o THRESHOLD = 7')
printClassificationResults(y_test_class7)
# Out:
# =============================
# Métricas para o THRESHOLD = 7
# Métricas por classe:
# Precisão: [0.79411765 0.3814433  0.30245747]
# Recall: [0.12328767 0.13857678 0.91954023]
# F1-Score: [0.21343874 0.2032967  0.45519203]
# AUC Médio: [0.55370733 0.49295251 0.58014049]
#
# Média das métricas:
# Acurácia: 0.3393939393939394
# Precisão: 0.3393939393939394
# Recall: 0.3393939393939394
# F1-Score: 0.3393939393939394
# AUC Médio: 0.5045454545454545

# %% [markdown]
# Mostrar as métricas de Classificação

# %%
# from sklearn.metrics import roc_curve, auc
# import matplotlib.pyplot as plt

# def plotROC(y_true, y_score, class_names):
#     n_classes = len(class_names)

#     # Inicialize a figura do gráfico
#     plt.figure(figsize=(8, 6))

#     # Defina as cores para as curvas ROC
#     colors = ['b', 'g', 'r', 'c', 'm', 'y', 'k']

#     # Plote as curvas ROC para cada classe
#     for i in range(n_classes):
#         fpr, tpr, _ = roc_curve(y_true[:, i], y_score[:, i])
#         roc_auc = auc(fpr, tpr)
#         plt.plot(fpr, tpr, color=colors[i], lw=2, label=f'Class {class_names[i]} (AUC = {roc_auc:.2f})')

#     # Plot the random chance line
#     plt.plot([0, 1], [0, 1], 'k--', lw=2, label='Random Chance')

#     # Customize the plot
#     plt.xlim([0.0, 1.0])
#     plt.ylim([0.0, 1.05])
#     plt.xlabel('False Positive Rate')
#     plt.ylabel('True Positive Rate')
#     plt.title('ROC Curves for Multiclass Classification')
#     plt.legend(loc='lower right')
#     plt.show()

# # Supondo que y_test_class_bin e y_test_class_predict_bin são matrizes com as probabilidades das classes
# class_names = [0, 1, 2]  # Nomes das classes ou rótulos
# plotROC(y_test_class_bin, y_test_class_predict_bin, class_names)

# %%
# Calcule o AUC médio para todas as classes
# None (padrão): Nesse caso, o AUC é calculado separadamente para cada classe e retornado como uma matriz. Não é um AUC médio.
# micro: Calcula o AUC médio considerando todas as instâncias individualmente. Ele faz isso tratando todas as previsões como uma única matriz de valores verdadeiros e previstos, e, em seguida, calculando o AUC.
# macro: Calcula o AUC médio para cada classe individualmente e, em seguida, tira a média desses valores. Isso atribui o mesmo peso a cada classe, independentemente do número de instâncias em cada classe.
# weighted: Calcula o AUC médio para cada classe individualmente e, em seguida, tira a média desses valores, dando pesos iguais a cada classe com base no número de instâncias na classe. Classes com mais instâncias têm um peso maior.
# https://scikit-learn.org/stable/auto_examples/model_selection/plot_roc.html
# In a multi-class classification setup with highly imbalanced classes, micro-averaging is preferable over macro-averaging. In such cases, one can alternatively use a weighted macro-averaging, not demoed here.
# Micro (average='micro'): Nessa abordagem, o AUC médio é calculado considerando todas as instâncias (amostras de dados) individualmente, independentemente da classe a que pertencem. Todas as previsões e rótulos verdadeiros são tratados como se fossem de uma única classe. Isso significa que cada instância tem o mesmo peso na métrica, independentemente de qual classe ela pertença. É como se todas as instâncias fossem combinadas em uma única classe para calcular o AUC.
# Em resumo, a abordagem "micro" calcula o AUC médio considerando todas as instâncias individualmente, sem considerar as classes. Isso significa que o desempenho geral do modelo é avaliado sem levar em consideração a estrutura de várias classes no problema de classificação. Essa abordagem é útil quando você deseja avaliar o desempenho global do modelo em todas as instâncias de forma igual.
# Se você usar average='None', obterá métricas para cada classe separadamente, o que pode ser útil se você estiver interessado no desempenho específico de cada classe.
# Se você usar average='micro', estará avaliando o desempenho geral do modelo, considerando igualmente todas as instâncias, independentemente da classe a que pertencem.
# Se você usar average='macro', todas as classes são tratadas igualmente, independentemente do número de instâncias em cada classe.
# Se você usar average='weighted', as classes são tratadas com pesos iguais ao número de instâncias em cada classe.

# %%
# Esses resultados indicam que, embora o modelo possa ter um desempenho globalmente bom, ele pode estar tendo dificuldade em discriminar entre classes individuais. Os resultados com average=None estão indicando que o modelo não está fazendo melhor do que uma classificação aleatória (AUC de 0.5) para cada classe em relação às outras.

# Portanto, ao avaliar o desempenho de um modelo multiclasse, é importante considerar não apenas a AUC global, mas também as AUCs individuais para cada classe, pois essas métricas podem fornecer insights valiosos sobre como o modelo está se saindo em relação a cada classe específica.
# O AUC micro é uma métrica que leva em consideração o desempenho global do classificador em relação a todas as classes, agregando as estatísticas de desempenho de todas as classes em uma única métrica.

# %%
# from sklearn.metrics import roc_curve
# import matplotlib.pyplot as plt

# def plotCurveROC(class_id):
#   # Calcule a curva ROC
#   fpr, tpr, _ = roc_curve(y_test_class_bin[:, class_id], y_test_class_predict_bin[:, class_id])

#   # Plote a curva ROC
#   plt.figure()
#   plt.plot(fpr, tpr, color='darkorange', lw=2, label=f"Classe {class_id} vs o restante")
#   plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
#   plt.xlim([0.0, 1.0])
#   plt.ylim([0.0, 1.05])
#   plt.xlabel('Taxa de falsos positivos')
#   plt.ylabel('Taxa de verdadeirospositivos')
#   plt.title(f'ROC Curve for Class {class_id}')
#   plt.legend(loc='lower right')
#   plt.show()

# plotCurveROC(0)
# plotCurveROC(1)
# plotCurveROC(2)

# %%
output_file.close()

# %%
# Calcular e imprimir as métricas de regressão
# mse = mean_squared_error(y_val, y_val_predict_results)
# rmse = np.sqrt(mse)
# mae = mean_absolute_error(y_val, y_val_predict_results)
# r2 = r2_score(y_val, y_val_predict_results)
# mape = np.mean(np.abs((y_val - y_val_predict_results) / y_val)) * 100

# %%
# y_val_predict.shape
# (303, 30, 1)
# 303: This is the number of data points or samples in your validation dataset. Each data point represents one day.
# 30: These are the time steps or sequence length used for making predictions. In your LSTM model, you are considering a sequence of 30 time steps to predict the next value.
# 1: This is the number of features being predicted. In your case, you are predicting the closing price of Bitcoin, which is a single numerical value.

# %%
# # Código para mais de uma camada de LSTM
# def build_multilayer_lstm_model(hp):
#   model = keras.Sequential()
#   for _ in range(hp.Int('num_lstm_layers', min_value=1, max_value=4)):
#       model.add(LSTM(
#           units=hp.Int('num_lstm_units', min_value=16, max_value=128, step=16),
#           return_sequences=True,
#           input_shape = (x_train.shape[1], x_train.shape[2]),
#           activation='relu'
#           ))
#       model.add(Dropout(hp.Float('dropout_rate', min_value=0.2, max_value=0.4)))
#   model.add(Dense(1))

#   optimizer = Adam(learning_rate=hp.Float('learning_rate', min_value=0.001, max_value=0.1, sampling='log'))
#   model.compile(loss='mean_squared_error', optimizer=optimizer)

#   return model
